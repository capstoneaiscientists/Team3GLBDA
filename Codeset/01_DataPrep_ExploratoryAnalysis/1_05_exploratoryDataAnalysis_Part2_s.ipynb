# %% [markdown]
# <html>
# <font color = Purple size =4>
# <b> Exploratory Analysis </b>
# </font>
# </html>

# %%
import pandas as pd

# %%
df_final = pd.read_csv("newlogs.csv", usecols = ['QueryTime','QuerySeq','AvatarID','Guild','Level','Race','Class','Zone'])

# %%
df_final.tail(5)
# Out:
#                    QueryTime  QuerySeq  AvatarID Guild  Level        Race  \
# 40692952   01/10/09 05:08:48        56     36893   104     80   Blood Elf
# 40692953   01/10/09 05:08:48        56     39532   204     80   Blood Elf
# 40692954   01/10/09 05:08:59        58     90033   502     80   Blood Elf
# 40692955   01/10/09 05:08:59        58     87974   251     80   Blood Elf
# 40692956   01/10/09 05:08:59        58     86679   459     80   Blood Elf
#
#                   Class                     Zone
# 40692952           Mage                  Dalaran
# 40692953           Mage          The Storm Peaks
# 40692954   Death Knight           Sholazar Basin
# 40692955   Death Knight   Blade's Edge Mountains
# 40692956   Death Knight        Shadowmoon Valley

# %%
df_final.Class.unique()
# Out:
# array([' Warrior', ' Shaman', ' Hunter', ' Warlock', ' Rogue', ' Druid',
#        ' Mage', ' Priest', ' Paladin', ' Death Knight'], dtype=object)

# %%
df_final.Zone.nunique()
# Out:
# 157

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
pwd
# Out:
# 'E:\\Sulekhas BOOKSHELF\\GreatLakes\\CapStoneProject\\Topics\\MyCode\\codeset'

# %%
df_final[df_final['Zone'].isin([' The Great Sea'])]
# Out:
#                    QueryTime  QuerySeq  AvatarID Guild  Level        Race  \
# 17472959   03/18/07 01:29:52        36     22536   104     60       Troll
# 17607574   03/26/07 02:09:48        23     26473   104     60      Tauren
# 17618594   03/26/07 17:09:05        15     30131   104     16      Tauren
# 17841220   04/02/07 02:35:07        15     32998    53     19      Tauren
# 17875028   04/03/07 11:59:33        20     19915           57      Tauren
# 17984519   04/05/07 12:12:48        12     33058   103     27      Tauren
# 18081465   04/06/07 21:35:11        40     21602     5     60      Undead
# 18851150   04/21/07 19:03:44        10     37414   189     18      Tauren
# 19212727   04/28/07 18:13:44        10     41901           17      Tauren
# 19304533   04/30/07 02:16:33        43     41425            4   Blood Elf
# 19732099   05/09/07 00:05:21        29     43535           10      Undead
# 20037868   05/16/07 02:09:50        50     41399           22   Blood Elf
# ...
